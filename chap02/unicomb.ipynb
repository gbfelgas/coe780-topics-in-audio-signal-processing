# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../src')
from unicomb import unicomb

# %%
N = 100
n = np.arange(N)
x = np.zeros(N)
x[0] = 1

# %%
plt.figure(figsize=(10, 5))
plt.plot(n, x)
plt.ylabel('x[n]')
plt.xlabel('n')
plt.grid(True)
plt.show()

# %%
BL = 0.5
FB = -0.5
FF = 1.
M = 10

# %%
y = unicomb(x, BL, FB, FF, M)

# %%
plt.figure(figsize=(20,10))
plt.plot(n, y)
plt.ylabel('y[n]')
plt.xlabel('n')
plt.grid(True)
plt.show()
